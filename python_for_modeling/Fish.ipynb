# %%
import numpy as np
import pandas as pd
from pathlib import Path
import os.path
from sklearn.model_selection import train_test_split
import tensorflow as tf

# %%
import shutil

# %%
image_dir = Path('.\image_data\database5\Fish_Dataset')

# %%
list(image_dir.glob(r'**/*.png'))
# Out:
# [WindowsPath('image_data/database5/Fish_Dataset/ArcticCharFish/3-Figure1-1.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/ArcticCharFish/383_2118.zt.800.800.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/ArcticCharFish/383_5585.zt.360.240.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/ArcticCharFish/4-Timing-of-the-upstream-migration-of-various-anadromous-arctic-char-populations-in.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/ArcticCharFish/5b035a9e-16f4-4ee5-b980-9ee9d8738800_m.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/ArcticCharFish/7-Figure3-1.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/ArcticCharFish/A-Arctic-char-Salvelinus-alpinus-from-Happy-Creek-Lake-Aleknagik-AK-note-the-silver.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/ArcticCharFish/A-small-Arctic-char-found-in-Ireland-top-a-pollan-found-in-Irish-freshwaters.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/ArcticCharFish/Alpine_Charr_preview_421a8eae-fb8d-4c7d-8b51-37a7112f85b1_1024x1024.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/ArcticCharFish/arctic-char-630x339.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/ArcticCharFish/arctic-char.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/ArcticCharFish/arcticchar.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/ArcticCharFish/arctic_char.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/ArcticCharFish/arctic_char_vs_dolly_varden.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/ArcticCharFish/attraqua-etikett-rC3B8ye-engelsk-web.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/ArcticCharFish/char-1351x600.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/ArcticCharFish/Kuori_char.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/ArcticCharFish/largepreview.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/ArcticCharFish/mages-of-three-body-size-morphs-of-Arctic-char-from-Lower-Tazimina-Lake-southwestern.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/ArcticCharFish/Screen_Shot_2017-10-04_at_11.50.00_AM_large.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/bassfish/1-bass-catch-fishing-sim-world-watermark-.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/bassfish/134-1342992_bass-fishing-png-bass-fish-png.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/bassfish/850259.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/bassfish/850303.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/bassfish/bass-fish-artwork-5.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/bassfish/Bass-Fishing-From-the-Bank-2.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/bassfish/Bass-Fishing-Kentucky-2.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/bassfish/Bass-Fishing-Kentucky-3.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/bassfish/Bass-Fishing-Pennsylvania1.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/bassfish/Bass-Fishing-Pennsylvania2.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/bassfish/Bass-Fishing-Pennsylvania3.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/bassfish/bass.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/bassfish/bass_fish_png_98887.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/bassfish/Billy20Driessen.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/bassfish/Cannon.Plowman_-_Bass.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/bassfish/Deeper_Hero_main-min.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/bassfish/fish-salmon-with-water-png-6.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/bassfish/gerry-gostenik-2-northern-smallies-cleared-lake-st-clair-smallmouth-bass-fishing-guide-detroit-michigan-400-233.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/bassfish/how-to-catch-big-bass.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/bassfish/I-340-Bass-Fishing_grande_b0bc2cea-c0b4-4ebd-8cfb-c68a17ab4587.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/bassfish/Jim-Jarvis-1.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/bassfish/largemouth-basses.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/bassfish/large_mouth_bass.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/bassfish/last-fishing-charter-669x272.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/bassfish/Muskie-Fishing-Videos-5.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/bassfish/page-image-11831-2a8a71b0-8d50-4a02-a491-7464fcd724c8.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/bassfish/peacock-bass.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/bassfish/Rainbowbass.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/bassfish/sandbass.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/bassfish/smallmouth-bass-fishing.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/bassfish/smallmouthbass2.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00001.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00002.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00003.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00004.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00005.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00006.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00007.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00008.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00009.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00010.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00011.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00012.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00013.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00014.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00015.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00016.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00017.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00018.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00019.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00020.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00021.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00022.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00023.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00024.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00025.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00026.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00027.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00028.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00029.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00030.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00031.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00032.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00033.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00034.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00035.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00036.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00037.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00038.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00039.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00040.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00041.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00042.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00043.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00044.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00045.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00046.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00047.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00048.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00049.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00050.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00051.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00052.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00053.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00054.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00055.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00056.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00057.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00058.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00059.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00060.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00061.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00062.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00063.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00064.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00065.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00066.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00067.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00068.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00069.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00070.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00071.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00072.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00073.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00074.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00075.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00076.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00077.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00078.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00079.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00080.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00081.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00082.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00083.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00084.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00085.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00086.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00087.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00088.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00089.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00090.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00091.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00092.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00093.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00094.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00095.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00096.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00097.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00098.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00099.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00100.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00101.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00102.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00103.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00104.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00105.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00106.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00107.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00108.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00109.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00110.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00111.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00112.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00113.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00114.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00115.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00116.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00117.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00118.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00119.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00120.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00121.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00122.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00123.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00124.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00125.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00126.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00127.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00128.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00129.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00130.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00131.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00132.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00133.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00134.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00135.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00136.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00137.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00138.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00139.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00140.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00141.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00142.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00143.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00144.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00145.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00146.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00147.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00148.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00149.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00150.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00151.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00152.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00153.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00154.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00155.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00156.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00157.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00158.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00159.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00160.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00161.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00162.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00163.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00164.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00165.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00166.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00167.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00168.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00169.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00170.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00171.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00172.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00173.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00174.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00175.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00176.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00177.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00178.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00179.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00180.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00181.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00182.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00183.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00184.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00185.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00186.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00187.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00188.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00189.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00190.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00191.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00192.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00193.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00194.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00195.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00196.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00197.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00198.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00199.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00200.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00201.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00202.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00203.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00204.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00205.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00206.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00207.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00208.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00209.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00210.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00211.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00212.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00213.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00214.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00215.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00216.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00217.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00218.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00219.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00220.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00221.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00222.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00223.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00224.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00225.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00226.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00227.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00228.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00229.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00230.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00231.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00232.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00233.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00234.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00235.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00236.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00237.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00238.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00239.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00240.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00241.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00242.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00243.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00244.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00245.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00246.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00247.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00248.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00249.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00250.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00251.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00252.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00253.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00254.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00255.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00256.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00257.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00258.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00259.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00260.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00261.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00262.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00263.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00264.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00265.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00266.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00267.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00268.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00269.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00270.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00271.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00272.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00273.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00274.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00275.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00276.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00277.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00278.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00279.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00280.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00281.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00282.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00283.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00284.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00285.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00286.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00287.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00288.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00289.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00290.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00291.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00292.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00293.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00294.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00295.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00296.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00297.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00298.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00299.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00300.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00301.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00302.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00303.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00304.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00305.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00306.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00307.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00308.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00309.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00310.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00311.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00312.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00313.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00314.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00315.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00316.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00317.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00318.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00319.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00320.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00321.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00322.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00323.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00324.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00325.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00326.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00327.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00328.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00329.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00330.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00331.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00332.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00333.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00334.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00335.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00336.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00337.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00338.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00339.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00340.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00341.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00342.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00343.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00344.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00345.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00346.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00347.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00348.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00349.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00350.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00351.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00352.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00353.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00354.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00355.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00356.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00357.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00358.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00359.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00360.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00361.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00362.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00363.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00364.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00365.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00366.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00367.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00368.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00369.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00370.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00371.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00372.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00373.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00374.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00375.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00376.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00377.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00378.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00379.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00380.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00381.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00382.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00383.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00384.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00385.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00386.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00387.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00388.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00389.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00390.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00391.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00392.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00393.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00394.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00395.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00396.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00397.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00398.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00399.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00400.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00401.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00402.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00403.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00404.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00405.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00406.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00407.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00408.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00409.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00410.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00411.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00412.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00413.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00414.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00415.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00416.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00417.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00418.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00419.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00420.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00421.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00422.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00423.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00424.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00425.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00426.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00427.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00428.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00429.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00430.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00431.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00432.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00433.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00434.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00435.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00436.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00437.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00438.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00439.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00440.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00441.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00442.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00443.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00444.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00445.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00446.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00447.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00448.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00449.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00450.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00451.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00452.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00453.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00454.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00455.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00456.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00457.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00458.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00459.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00460.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00461.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00462.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00463.png'),
# ...
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00779.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00780.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00781.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00782.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00783.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00784.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00785.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00786.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00787.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00788.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00789.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00790.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00791.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00792.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00793.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00794.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00795.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00796.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00797.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00798.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00799.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00800.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00801.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00802.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00803.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00804.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00805.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00806.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00807.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00808.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00809.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00810.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00811.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00812.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00813.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00814.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00815.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00816.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00817.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00818.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00819.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00820.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00821.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00822.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00823.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00824.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00825.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00826.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00827.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00828.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00829.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00830.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00831.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00832.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00833.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00834.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00835.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00836.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00837.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00838.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00839.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00840.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00841.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00842.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00843.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00844.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00845.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00846.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00847.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00848.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00849.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00850.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00851.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00852.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00853.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00854.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00855.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00856.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00857.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00858.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00859.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00860.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00861.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00862.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00863.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00864.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00865.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00866.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00867.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00868.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00869.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00870.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00871.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00872.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00873.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00874.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00875.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00876.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00877.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00878.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00879.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00880.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00881.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00882.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00883.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00884.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00885.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00886.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00887.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00888.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00889.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00890.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00891.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00892.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00893.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00894.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00895.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00896.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00897.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00898.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00899.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00900.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00901.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00902.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00903.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00904.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00905.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00906.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00907.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00908.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00909.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00910.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00911.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00912.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00913.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00914.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00915.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00916.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00917.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00918.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00919.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00920.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00921.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00922.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00923.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00924.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00925.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00926.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00927.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00928.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00929.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00930.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00931.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00932.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00933.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00934.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00935.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00936.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00937.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00938.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00939.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00940.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00941.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00942.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00943.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00944.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00945.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00946.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00947.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00948.png'),
#  WindowsPath('image_data/database5/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00949.png'),
#  ...]

# %%
filepaths = list(image_dir.glob(r'**/*.png')) + list(image_dir.glob(r'**/*.jpg'))
labels = list(map(lambda x: os.path.split(os.path.split(x)[0])[1], filepaths))

filepaths = pd.Series(filepaths, name='Filepath').astype(str)
labels = pd.Series(labels, name='Label')

# Concatenate filepaths and labels
image_df = pd.concat([filepaths, labels], axis=1)

# Drop GT images
image_df['Label'] = image_df['Label'].apply(lambda x: np.NaN if x[-2:] == 'GT' else x)
image_df = image_df.dropna(axis=0)

samples = []

for category in image_df['Label'].unique():
    category_slice = image_df.query("Label == @category")
    if len(category_slice) < 350:
        samples.append(category_slice.sample(350, replace=True, random_state=1))
    else:
        samples.append(category_slice.sample(350, random_state=1))

image_df = pd.concat(samples, axis=0).sample(frac=1.0, random_state=1).reset_index(drop=True)

# %%
image_df
# Out:
#                                                Filepath               Label
# 0     image_data\database5\Fish_Dataset\Red Sea Brea...       Red Sea Bream
# 1     image_data\database5\Fish_Dataset\Red-snapper\...         Red-snapper
# 2     image_data\database5\Fish_Dataset\Gilt-Head Br...     Gilt-Head Bream
# 3     image_data\database5\Fish_Dataset\Black Sea Sp...     Black Sea Sprat
# 4     image_data\database5\Fish_Dataset\Trout\Trout\...               Trout
# ...                                                 ...                 ...
# 6645  image_data\database5\Fish_Dataset\Black Sea Sp...     Black Sea Sprat
# 6646  image_data\database5\Fish_Dataset\Striped Red ...  Striped Red Mullet
# 6647  image_data\database5\Fish_Dataset\SardineFish\...         SardineFish
# 6648  image_data\database5\Fish_Dataset\ArcticCharFi...      ArcticCharFish
# 6649  image_data\database5\Fish_Dataset\Striped Red ...  Striped Red Mullet
#
# [6650 rows x 2 columns]

# %%
labels
# Out:
# 0        ArcticCharFish
# 1        ArcticCharFish
# 2        ArcticCharFish
# 3        ArcticCharFish
# 4        ArcticCharFish
#               ...
# 27089              tuna
# 27090              tuna
# 27091              tuna
# 27092              tuna
# 27093              tuna
# Name: Label, Length: 27094, dtype: object

# %%
image_df
# Out:
#                                                Filepath               Label
# 0     image_data\database5\Fish_Dataset\Red Sea Brea...       Red Sea Bream
# 1     image_data\database5\Fish_Dataset\Red-snapper\...         Red-snapper
# 2     image_data\database5\Fish_Dataset\Gilt-Head Br...     Gilt-Head Bream
# 3     image_data\database5\Fish_Dataset\Black Sea Sp...     Black Sea Sprat
# 4     image_data\database5\Fish_Dataset\Trout\Trout\...               Trout
# ...                                                 ...                 ...
# 6645  image_data\database5\Fish_Dataset\Black Sea Sp...     Black Sea Sprat
# 6646  image_data\database5\Fish_Dataset\Striped Red ...  Striped Red Mullet
# 6647  image_data\database5\Fish_Dataset\SardineFish\...         SardineFish
# 6648  image_data\database5\Fish_Dataset\ArcticCharFi...      ArcticCharFish
# 6649  image_data\database5\Fish_Dataset\Striped Red ...  Striped Red Mullet
#
# [6650 rows x 2 columns]

# %%
train_df, test_df = train_test_split(image_df, train_size=0.7, shuffle=True, random_state=1)

# %%
def create_category_folders(base_dir, categories):
    for category in categories:
        category_path = os.path.join(base_dir, category)
        os.makedirs(category_path, exist_ok=True)

def move_files(df, base_dir):
    for _, row in df.iterrows():
        category = row['Label']
        file_path = row['Filepath']
        destination_dir = os.path.join(base_dir, category)
        shutil.copy(file_path, destination_dir)

def organize_train_test_data(train_df, test_df, base_dir='organized_data'):
    # Create base directories for training and testing
    train_dir = os.path.join(base_dir, 'train')
    test_dir = os.path.join(base_dir, 'test')
    os.makedirs(train_dir, exist_ok=True)
    os.makedirs(test_dir, exist_ok=True)

    # Get unique categories from the DataFrame
    categories = train_df['Label'].unique()

    # Create category folders for both train and test directories
    create_category_folders(train_dir, categories)
    create_category_folders(test_dir, categories)

    # Move the training and testing files to the respective directories
    move_files(train_df, train_dir)
    move_files(test_df, test_dir)

    print("Files have been organized into train and test folders.")

# Step 7: Organize the train and test data
organize_train_test_data(train_df, test_df, base_dir='organized_data')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[28], line 34
#      31     print("Files have been organized into train and test folders.")
#      33 # Step 7: Organize the train and test data
# ---> 34 organize_train_test_data(train_df, test_df, base_dir='organized_data')
#
# Cell In[28], line 28, in organize_train_test_data(train_df, test_df, base_dir)
#      25 create_category_folders(test_dir, categories)
#      27 # Move the training and testing files to the respective directories
# ---> 28 move_files(train_df, train_dir)
#      29 move_files(test_df, test_dir)
#      31 print("Files have been organized into train and test folders.")
#
# Cell In[28], line 11, in move_files(df, base_dir)
#       9 file_path = row['Filepath']
#      10 destination_dir = os.path.join(base_dir, category)
# ---> 11 shutil.copy(file_path, destination_dir)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\shutil.py:431, in copy(src, dst, follow_symlinks)
#     429 if os.path.isdir(dst):
#     430     dst = os.path.join(dst, os.path.basename(src))
# --> 431 copyfile(src, dst, follow_symlinks=follow_symlinks)
#     432 copymode(src, dst, follow_symlinks=follow_symlinks)
#     433 return dst
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\shutil.py:276, in copyfile(src, dst, follow_symlinks)
#     273 # Windows, see:
#     274 # https://github.com/python/cpython/pull/7160#discussion_r195405230
#     275 elif _WINDOWS and file_size > 0:
# --> 276     _copyfileobj_readinto(fsrc, fdst, min(file_size, COPY_BUFSIZE))
#     277     return dst
#     279 copyfileobj(fsrc, fdst)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\shutil.py:180, in _copyfileobj_readinto(fsrc, fdst, length)
#     178 with memoryview(bytearray(length)) as mv:
#     179     while True:
# --> 180         n = fsrc_readinto(mv)
#     181         if not n:
#     182             break
#
# KeyboardInterrupt:

# %%
train_generator = tf.keras.preprocessing.image.ImageDataGenerator(
    preprocessing_function=tf.keras.applications.mobilenet_v2.preprocess_input,
    validation_split=0.2
)

test_generator = tf.keras.preprocessing.image.ImageDataGenerator(
    preprocessing_function=tf.keras.applications.mobilenet_v2.preprocess_input
)

# %%
train_images = train_generator.flow_from_dataframe(
    dataframe=train_df,
    x_col='Filepath',
    y_col='Label',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=42,
    subset='training'
)

val_images = train_generator.flow_from_dataframe(
    dataframe=train_df,
    x_col='Filepath',
    y_col='Label',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=42,
    subset='validation'
)

test_images = test_generator.flow_from_dataframe(
    dataframe=test_df,
    x_col='Filepath',
    y_col='Label',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=32,
    shuffle=False
)
# Out:
# Found 3724 validated image filenames belonging to 19 classes.
# Found 931 validated image filenames belonging to 19 classes.
# Found 1995 validated image filenames belonging to 19 classes.

# %%
train_class_indices = train_images.class_indices
print("Class indices in training set:", train_class_indices)

# Reverse the dictionary to map indices to class names
index_to_class = {v: k for k, v in train_class_indices.items()}
print("Index to class mapping:", index_to_class)
# Out:
# Class indices in training set: {'ArcticCharFish': 0, 'Black Sea Sprat': 1, 'Gilt-Head Bream': 2, 'Hourse Mackerel': 3, 'Red Mullet': 4, 'Red Sea Bream': 5, 'Red-snapper': 6, 'SardineFish': 7, 'Sea Bass': 8, 'Shrimp': 9, 'Striped Red Mullet': 10, 'TilapiaFish': 11, 'Trout': 12, 'bassfish': 13, 'catfish': 14, 'haddockfish': 15, 'salmon': 16, 'swordfish': 17, 'tuna': 18}
# Index to class mapping: {0: 'ArcticCharFish', 1: 'Black Sea Sprat', 2: 'Gilt-Head Bream', 3: 'Hourse Mackerel', 4: 'Red Mullet', 5: 'Red Sea Bream', 6: 'Red-snapper', 7: 'SardineFish', 8: 'Sea Bass', 9: 'Shrimp', 10: 'Striped Red Mullet', 11: 'TilapiaFish', 12: 'Trout', 13: 'bassfish', 14: 'catfish', 15: 'haddockfish', 16: 'salmon', 17: 'swordfish', 18: 'tuna'}

# %%
base_model = tf.keras.applications.MobileNetV2(
    input_shape=(224, 224, 3),
    include_top=False,
    weights='imagenet',
    pooling='avg'
)

base_model.trainable = False

# %%
inputs = base_model.input

x = tf.keras.layers.Dense(128, activation='relu')(base_model.output)
x = tf.keras.layers.Dense(128, activation='relu')(x)

outputs = tf.keras.layers.Dense(19, activation='softmax')(x)


model = tf.keras.Model(inputs=inputs, outputs=outputs)


model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
history = model.fit(
    train_images,
    validation_data=val_images,
    epochs=100,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(
            monitor='val_loss',
            patience=3,
            restore_best_weights=True
        )
    ]
)
# Out:
# Epoch 1/100
# d:\Projuct_\Project_code\python_for_modeling\.venv\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
#  58/117 ━━━━━━━━━━━━━━━━━━━━ 32s 547ms/step - accuracy: 0.3665 - loss: 2.1011
# d:\Projuct_\Project_code\python_for_modeling\.venv\Lib\site-packages\PIL\Image.py:1056: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 94s 730ms/step - accuracy: 0.4885 - loss: 1.6964 - val_accuracy: 0.7669 - val_loss: 0.7229
# Epoch 2/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 86s 718ms/step - accuracy: 0.8279 - loss: 0.5234 - val_accuracy: 0.7981 - val_loss: 0.6350
# Epoch 3/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 86s 718ms/step - accuracy: 0.8955 - loss: 0.3420 - val_accuracy: 0.8034 - val_loss: 0.6300
# Epoch 4/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 84s 706ms/step - accuracy: 0.9329 - loss: 0.2416 - val_accuracy: 0.8077 - val_loss: 0.6667
# Epoch 5/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 85s 717ms/step - accuracy: 0.9685 - loss: 0.1430 - val_accuracy: 0.8002 - val_loss: 0.7086
# Epoch 6/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 85s 714ms/step - accuracy: 0.9757 - loss: 0.1065 - val_accuracy: 0.8142 - val_loss: 0.7084

# %%
# Unfreeze the top layers of the base model for fine-tuning
base_model.trainable = True
for layer in base_model.layers[:-20]:  # Freeze all but the last 20 layers
    layer.trainable = False

# Re-compile the model with a lower learning rate for fine-tuning
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Continue training with fine-tuning
history_fine_tune = model.fit(
    train_images,
    validation_data=val_images,
    epochs=50,  # Fine-tuning for fewer epochs
    callbacks=[
        tf.keras.callbacks.EarlyStopping(
            monitor='val_loss',
            patience=3,
            restore_best_weights=True
        )
    ]
)
# Out:
# Epoch 1/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 111s 825ms/step - accuracy: 0.7272 - loss: 0.8658 - val_accuracy: 0.8110 - val_loss: 0.6116
# Epoch 2/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 95s 799ms/step - accuracy: 0.8958 - loss: 0.4004 - val_accuracy: 0.8110 - val_loss: 0.6073
# Epoch 3/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 98s 823ms/step - accuracy: 0.9259 - loss: 0.3128 - val_accuracy: 0.8120 - val_loss: 0.6036
# Epoch 4/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 96s 806ms/step - accuracy: 0.9385 - loss: 0.2747 - val_accuracy: 0.8120 - val_loss: 0.5988
# Epoch 5/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 95s 802ms/step - accuracy: 0.9533 - loss: 0.2274 - val_accuracy: 0.8131 - val_loss: 0.5934
# Epoch 6/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 95s 800ms/step - accuracy: 0.9572 - loss: 0.2203 - val_accuracy: 0.8163 - val_loss: 0.5903
# Epoch 7/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 96s 804ms/step - accuracy: 0.9563 - loss: 0.2020 - val_accuracy: 0.8153 - val_loss: 0.5834
# Epoch 8/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 98s 826ms/step - accuracy: 0.9719 - loss: 0.1679 - val_accuracy: 0.8163 - val_loss: 0.5864
# Epoch 9/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 98s 821ms/step - accuracy: 0.9759 - loss: 0.1462 - val_accuracy: 0.8153 - val_loss: 0.5868
# Epoch 10/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 98s 820ms/step - accuracy: 0.9752 - loss: 0.1337 - val_accuracy: 0.8238 - val_loss: 0.5828
# Epoch 11/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 97s 818ms/step - accuracy: 0.9798 - loss: 0.1298 - val_accuracy: 0.8217 - val_loss: 0.5832
# Epoch 12/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 98s 818ms/step - accuracy: 0.9876 - loss: 0.1053 - val_accuracy: 0.8238 - val_loss: 0.5828
# Epoch 13/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 98s 819ms/step - accuracy: 0.9851 - loss: 0.1017 - val_accuracy: 0.8238 - val_loss: 0.5882

# %%
results = model.evaluate(test_images, verbose=0)

print("    Test Loss: {:.5f}".format(results[0]))
print("Test Accuracy: {:.2f}%".format(results[1] * 100))
# Out:
#     Test Loss: 0.57573
# Test Accuracy: 83.06%

# %%
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv1 (Conv2D)      │ (None, 112, 112,  │        864 │ input_layer_2[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bn_Conv1            │ (None, 112, 112,  │        128 │ Conv1[0][0]       │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv1_relu (ReLU)   │ (None, 112, 112,  │          0 │ bn_Conv1[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 112, 112,  │        288 │ Conv1_relu[0][0]  │
# │ (DepthwiseConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 112, 112,  │        128 │ expanded_conv_de… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 112, 112,  │          0 │ expanded_conv_de… │
# │ (ReLU)              │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_proj… │ (None, 112, 112,  │        512 │ expanded_conv_de… │
# │ (Conv2D)            │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_proj… │ (None, 112, 112,  │         64 │ expanded_conv_pr… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_expand      │ (None, 112, 112,  │      1,536 │ expanded_conv_pr… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_expand_BN   │ (None, 112, 112,  │        384 │ block_1_expand[0… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_expand_relu │ (None, 112, 112,  │          0 │ block_1_expand_B… │
# │ (ReLU)              │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_pad         │ (None, 113, 113,  │          0 │ block_1_expand_r… │
# │ (ZeroPadding2D)     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_depthwise   │ (None, 56, 56,    │        864 │ block_1_pad[0][0] │
# │ (DepthwiseConv2D)   │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_depthwise_… │ (None, 56, 56,    │        384 │ block_1_depthwis… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_depthwise_… │ (None, 56, 56,    │          0 │ block_1_depthwis… │
# │ (ReLU)              │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_project     │ (None, 56, 56,    │      2,304 │ block_1_depthwis… │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_project_BN  │ (None, 56, 56,    │         96 │ block_1_project[… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_expand      │ (None, 56, 56,    │      3,456 │ block_1_project_… │
# │ (Conv2D)            │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_expand_BN   │ (None, 56, 56,    │        576 │ block_2_expand[0… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_expand_relu │ (None, 56, 56,    │          0 │ block_2_expand_B… │
# │ (ReLU)              │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_depthwise   │ (None, 56, 56,    │      1,296 │ block_2_expand_r… │
# │ (DepthwiseConv2D)   │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_depthwise_… │ (None, 56, 56,    │        576 │ block_2_depthwis… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_depthwise_… │ (None, 56, 56,    │          0 │ block_2_depthwis… │
# │ (ReLU)              │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_project     │ (None, 56, 56,    │      3,456 │ block_2_depthwis… │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_project_BN  │ (None, 56, 56,    │         96 │ block_2_project[… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_add (Add)   │ (None, 56, 56,    │          0 │ block_1_project_… │
# │                     │ 24)               │            │ block_2_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_expand      │ (None, 56, 56,    │      3,456 │ block_2_add[0][0] │
# │ (Conv2D)            │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_expand_BN   │ (None, 56, 56,    │        576 │ block_3_expand[0… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_expand_relu │ (None, 56, 56,    │          0 │ block_3_expand_B… │
# │ (ReLU)              │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_pad         │ (None, 57, 57,    │          0 │ block_3_expand_r… │
# │ (ZeroPadding2D)     │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_depthwise   │ (None, 28, 28,    │      1,296 │ block_3_pad[0][0] │
# │ (DepthwiseConv2D)   │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_depthwise_… │ (None, 28, 28,    │        576 │ block_3_depthwis… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_depthwise_… │ (None, 28, 28,    │          0 │ block_3_depthwis… │
# │ (ReLU)              │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_project     │ (None, 28, 28,    │      4,608 │ block_3_depthwis… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_project_BN  │ (None, 28, 28,    │        128 │ block_3_project[… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_expand      │ (None, 28, 28,    │      6,144 │ block_3_project_… │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_expand_BN   │ (None, 28, 28,    │        768 │ block_4_expand[0… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_expand_relu │ (None, 28, 28,    │          0 │ block_4_expand_B… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_depthwise   │ (None, 28, 28,    │      1,728 │ block_4_expand_r… │
# │ (DepthwiseConv2D)   │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_depthwise_… │ (None, 28, 28,    │        768 │ block_4_depthwis… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_depthwise_… │ (None, 28, 28,    │          0 │ block_4_depthwis… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_project     │ (None, 28, 28,    │      6,144 │ block_4_depthwis… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_project_BN  │ (None, 28, 28,    │        128 │ block_4_project[… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_add (Add)   │ (None, 28, 28,    │          0 │ block_3_project_… │
# │                     │ 32)               │            │ block_4_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_expand      │ (None, 28, 28,    │      6,144 │ block_4_add[0][0] │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_expand_BN   │ (None, 28, 28,    │        768 │ block_5_expand[0… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_expand_relu │ (None, 28, 28,    │          0 │ block_5_expand_B… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_depthwise   │ (None, 28, 28,    │      1,728 │ block_5_expand_r… │
# │ (DepthwiseConv2D)   │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_depthwise_… │ (None, 28, 28,    │        768 │ block_5_depthwis… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_depthwise_… │ (None, 28, 28,    │          0 │ block_5_depthwis… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_project     │ (None, 28, 28,    │      6,144 │ block_5_depthwis… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_project_BN  │ (None, 28, 28,    │        128 │ block_5_project[… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_add (Add)   │ (None, 28, 28,    │          0 │ block_4_add[0][0… │
# │                     │ 32)               │            │ block_5_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_expand      │ (None, 28, 28,    │      6,144 │ block_5_add[0][0] │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_expand_BN   │ (None, 28, 28,    │        768 │ block_6_expand[0… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_expand_relu │ (None, 28, 28,    │          0 │ block_6_expand_B… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_pad         │ (None, 29, 29,    │          0 │ block_6_expand_r… │
# │ (ZeroPadding2D)     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_depthwise   │ (None, 14, 14,    │      1,728 │ block_6_pad[0][0] │
# │ (DepthwiseConv2D)   │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_depthwise_… │ (None, 14, 14,    │        768 │ block_6_depthwis… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_depthwise_… │ (None, 14, 14,    │          0 │ block_6_depthwis… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_project     │ (None, 14, 14,    │     12,288 │ block_6_depthwis… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_project_BN  │ (None, 14, 14,    │        256 │ block_6_project[… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_expand      │ (None, 14, 14,    │     24,576 │ block_6_project_… │
# │ (Conv2D)            │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_expand_BN   │ (None, 14, 14,    │      1,536 │ block_7_expand[0… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_expand_relu │ (None, 14, 14,    │          0 │ block_7_expand_B… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_depthwise   │ (None, 14, 14,    │      3,456 │ block_7_expand_r… │
# │ (DepthwiseConv2D)   │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_depthwise_… │ (None, 14, 14,    │      1,536 │ block_7_depthwis… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_depthwise_… │ (None, 14, 14,    │          0 │ block_7_depthwis… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_project     │ (None, 14, 14,    │     24,576 │ block_7_depthwis… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_project_BN  │ (None, 14, 14,    │        256 │ block_7_project[… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_add (Add)   │ (None, 14, 14,    │          0 │ block_6_project_… │
# │                     │ 64)               │            │ block_7_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_expand      │ (None, 14, 14,    │     24,576 │ block_7_add[0][0] │
# │ (Conv2D)            │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_expand_BN   │ (None, 14, 14,    │      1,536 │ block_8_expand[0… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_expand_relu │ (None, 14, 14,    │          0 │ block_8_expand_B… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_depthwise   │ (None, 14, 14,    │      3,456 │ block_8_expand_r… │
# │ (DepthwiseConv2D)   │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_depthwise_… │ (None, 14, 14,    │      1,536 │ block_8_depthwis… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_depthwise_… │ (None, 14, 14,    │          0 │ block_8_depthwis… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_project     │ (None, 14, 14,    │     24,576 │ block_8_depthwis… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_project_BN  │ (None, 14, 14,    │        256 │ block_8_project[… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_add (Add)   │ (None, 14, 14,    │          0 │ block_7_add[0][0… │
# │                     │ 64)               │            │ block_8_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_expand      │ (None, 14, 14,    │     24,576 │ block_8_add[0][0] │
# │ (Conv2D)            │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_expand_BN   │ (None, 14, 14,    │      1,536 │ block_9_expand[0… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_expand_relu │ (None, 14, 14,    │          0 │ block_9_expand_B… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_depthwise   │ (None, 14, 14,    │      3,456 │ block_9_expand_r… │
# │ (DepthwiseConv2D)   │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_depthwise_… │ (None, 14, 14,    │      1,536 │ block_9_depthwis… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_depthwise_… │ (None, 14, 14,    │          0 │ block_9_depthwis… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_project     │ (None, 14, 14,    │     24,576 │ block_9_depthwis… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_project_BN  │ (None, 14, 14,    │        256 │ block_9_project[… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_add (Add)   │ (None, 14, 14,    │          0 │ block_8_add[0][0… │
# │                     │ 64)               │            │ block_9_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_expand     │ (None, 14, 14,    │     24,576 │ block_9_add[0][0] │
# │ (Conv2D)            │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_expand_BN  │ (None, 14, 14,    │      1,536 │ block_10_expand[… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_expand_re… │ (None, 14, 14,    │          0 │ block_10_expand_… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_depthwise  │ (None, 14, 14,    │      3,456 │ block_10_expand_… │
# │ (DepthwiseConv2D)   │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_depthwise… │ (None, 14, 14,    │      1,536 │ block_10_depthwi… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_depthwise… │ (None, 14, 14,    │          0 │ block_10_depthwi… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_project    │ (None, 14, 14,    │     36,864 │ block_10_depthwi… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_project_BN │ (None, 14, 14,    │        384 │ block_10_project… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_expand     │ (None, 14, 14,    │     55,296 │ block_10_project… │
# │ (Conv2D)            │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_expand_BN  │ (None, 14, 14,    │      2,304 │ block_11_expand[… │
# │ (BatchNormalizatio… │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_expand_re… │ (None, 14, 14,    │          0 │ block_11_expand_… │
# │ (ReLU)              │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_depthwise  │ (None, 14, 14,    │      5,184 │ block_11_expand_… │
# │ (DepthwiseConv2D)   │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_depthwise… │ (None, 14, 14,    │      2,304 │ block_11_depthwi… │
# │ (BatchNormalizatio… │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_depthwise… │ (None, 14, 14,    │          0 │ block_11_depthwi… │
# │ (ReLU)              │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_project    │ (None, 14, 14,    │     55,296 │ block_11_depthwi… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_project_BN │ (None, 14, 14,    │        384 │ block_11_project… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_add (Add)  │ (None, 14, 14,    │          0 │ block_10_project… │
# │                     │ 96)               │            │ block_11_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_expand     │ (None, 14, 14,    │     55,296 │ block_11_add[0][… │
# │ (Conv2D)            │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_expand_BN  │ (None, 14, 14,    │      2,304 │ block_12_expand[… │
# │ (BatchNormalizatio… │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_expand_re… │ (None, 14, 14,    │          0 │ block_12_expand_… │
# │ (ReLU)              │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_depthwise  │ (None, 14, 14,    │      5,184 │ block_12_expand_… │
# │ (DepthwiseConv2D)   │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_depthwise… │ (None, 14, 14,    │      2,304 │ block_12_depthwi… │
# │ (BatchNormalizatio… │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_depthwise… │ (None, 14, 14,    │          0 │ block_12_depthwi… │
# │ (ReLU)              │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_project    │ (None, 14, 14,    │     55,296 │ block_12_depthwi… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_project_BN │ (None, 14, 14,    │        384 │ block_12_project… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_add (Add)  │ (None, 14, 14,    │          0 │ block_11_add[0][… │
# │                     │ 96)               │            │ block_12_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_expand     │ (None, 14, 14,    │     55,296 │ block_12_add[0][… │
# │ (Conv2D)            │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_expand_BN  │ (None, 14, 14,    │      2,304 │ block_13_expand[… │
# │ (BatchNormalizatio… │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_expand_re… │ (None, 14, 14,    │          0 │ block_13_expand_… │
# │ (ReLU)              │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_pad        │ (None, 15, 15,    │          0 │ block_13_expand_… │
# │ (ZeroPadding2D)     │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_depthwise  │ (None, 7, 7, 576) │      5,184 │ block_13_pad[0][… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_depthwise… │ (None, 7, 7, 576) │      2,304 │ block_13_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_depthwise… │ (None, 7, 7, 576) │          0 │ block_13_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_project    │ (None, 7, 7, 160) │     92,160 │ block_13_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_project_BN │ (None, 7, 7, 160) │        640 │ block_13_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_expand     │ (None, 7, 7, 960) │    153,600 │ block_13_project… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_expand_BN  │ (None, 7, 7, 960) │      3,840 │ block_14_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_expand_re… │ (None, 7, 7, 960) │          0 │ block_14_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_depthwise  │ (None, 7, 7, 960) │      8,640 │ block_14_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_depthwise… │ (None, 7, 7, 960) │      3,840 │ block_14_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_depthwise… │ (None, 7, 7, 960) │          0 │ block_14_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_project    │ (None, 7, 7, 160) │    153,600 │ block_14_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_project_BN │ (None, 7, 7, 160) │        640 │ block_14_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_add (Add)  │ (None, 7, 7, 160) │          0 │ block_13_project… │
# │                     │                   │            │ block_14_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_expand     │ (None, 7, 7, 960) │    153,600 │ block_14_add[0][… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_expand_BN  │ (None, 7, 7, 960) │      3,840 │ block_15_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_expand_re… │ (None, 7, 7, 960) │          0 │ block_15_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_depthwise  │ (None, 7, 7, 960) │      8,640 │ block_15_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_depthwise… │ (None, 7, 7, 960) │      3,840 │ block_15_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_depthwise… │ (None, 7, 7, 960) │          0 │ block_15_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_project    │ (None, 7, 7, 160) │    153,600 │ block_15_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_project_BN │ (None, 7, 7, 160) │        640 │ block_15_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_add (Add)  │ (None, 7, 7, 160) │          0 │ block_14_add[0][… │
# │                     │                   │            │ block_15_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_expand     │ (None, 7, 7, 960) │    153,600 │ block_15_add[0][… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_expand_BN  │ (None, 7, 7, 960) │      3,840 │ block_16_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_expand_re… │ (None, 7, 7, 960) │          0 │ block_16_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_depthwise  │ (None, 7, 7, 960) │      8,640 │ block_16_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_depthwise… │ (None, 7, 7, 960) │      3,840 │ block_16_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_depthwise… │ (None, 7, 7, 960) │          0 │ block_16_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_project    │ (None, 7, 7, 320) │    307,200 │ block_16_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_project_BN │ (None, 7, 7, 320) │      1,280 │ block_16_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv_1 (Conv2D)     │ (None, 7, 7,      │    409,600 │ block_16_project… │
# │                     │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv_1_bn           │ (None, 7, 7,      │      5,120 │ Conv_1[0][0]      │
# │ (BatchNormalizatio… │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_relu (ReLU)     │ (None, 7, 7,      │          0 │ Conv_1_bn[0][0]   │
# │                     │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 1280)      │          0 │ out_relu[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 128)       │    163,968 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 128)       │     16,512 │ dense_3[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 19)        │      2,451 │ dense_4[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 4,911,739 (18.74 MB)
#  Trainable params: 1,235,411 (4.71 MB)
#  Non-trainable params: 1,205,504 (4.60 MB)
#  Optimizer params: 2,470,824 (9.43 MB)

# %%
import matplotlib.pyplot as plt
# Out:
# WARNING:matplotlib.font_manager:Matplotlib is building the font cache; this may take a moment.

# %%
kearas_file = "model/Fish_use.h5"
tf.keras.models.save_model(model,kearas_file)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tfmodel = converter.convert()
with open("./model/Fish_use.tflite","wb") as f:
    f.write(tfmodel)
# Out:
# INFO:tensorflow:Assets written to: C:\Users\KK\AppData\Local\Temp\tmppcy7yddu\assets
# INFO:tensorflow:Assets written to: C:\Users\KK\AppData\Local\Temp\tmppcy7yddu\assets
# Saved artifact at 'C:\Users\KK\AppData\Local\Temp\tmppcy7yddu'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='keras_tensor_313')
# Output Type:
#   TensorSpec(shape=(None, 19), dtype=tf.float32, name=None)
# Captures:
#   1757900101328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757900101520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757900102672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757900101904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757900101712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757900102480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757900102288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757900104592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757900103440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757900103056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757900104400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757900104208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757900106512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757900105360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757900104976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757900106320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757900106128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757900108432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757900107280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757900106896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757900108240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757900108048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757900110352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757900109200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757900108816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757900110160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757900636432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757900636624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757900110736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757900111504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757900636816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757900637008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757900638544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757900637392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757900637200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757900638352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757900638160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757900640464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757900639312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757900638928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757900640272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757900640080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757900642384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757900641232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757900640848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757900642192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757900642000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757900644304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757900643152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757900642768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757900644112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757900643920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757900646224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757900645072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757900644688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757900646032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757900645840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757900648144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757900646992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757900646608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757900647952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757900647760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757900650064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757900648912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757900648528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757900649872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757900651984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757900651600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757900650832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757900650448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901078608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901078800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901079952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901079184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901078992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901079760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901079568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901081872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901080720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901080336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901081680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901081488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901083792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901082640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901082256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901083600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901083408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901085712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901084560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901084176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901085520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901085328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901087632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901086480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901086096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901087440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901087248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901089552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901088400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901088016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901089360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901089168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901091472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901090320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901089936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901091280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901091088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901093392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901092240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901091856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901093200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901439248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901439440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901093776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901094544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901439632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901439824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901441360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901440208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901440016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901441168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901440976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901443280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901442128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901441744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901443088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901442896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901445200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901444048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901443664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901445008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901444816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901447120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901445968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901445584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901446928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901446736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901449040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901447888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901447504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901448848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901448656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901450960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901449808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901449424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901450768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901450576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901452880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901451728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901451344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901452688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901454800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901454416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901453648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901453264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901882192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901881808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901882768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901881616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901881424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901882576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901882384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901884688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901883536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901883152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901884496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901884304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901886608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901885456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901885072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901886416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901886224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901888528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901887376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901886992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901888336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901888144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901890448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901889296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901888912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901890256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901890064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901892368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901891216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901890832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901892176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901891984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901894288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901893136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901892752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901894096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901893904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901896208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901895056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901894672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901896016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757913792784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757913792976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901896592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757901897360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757913793168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757913793360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757913794896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757913793744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757913793552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757913794704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757913794512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757913796816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757913795664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757913795280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757913796624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757913796432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757913798736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757913797584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757913797200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757913798544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757913798352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757913800656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757913799504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757913799120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757913800464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757913800272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757913802576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757913801424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757913801040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757913802384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757913802192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757913804496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757913803344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757913802960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757913804304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757913804112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757913806416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757913805264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757913804880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757913806224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757913808336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757913807952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757913807184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757913806800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757914251344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757914251536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757914252688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757914251920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757914251728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757914252496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757914252304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757914254608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757914253456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757914253072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757914254416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757914254224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757914256528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757914255376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757914254992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757914256336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757914256144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757914258448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757914257296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757914256912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757914258256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757914258832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757914258064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757914259984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757914260176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1757914260752: TensorSpec(shape=(), dtype=tf.resource, name=None)
